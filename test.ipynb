# %% [markdown]
# <a href="https://colab.research.google.com/github/raxstarslays/classification-project/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello user")
# Out:
# hello user
